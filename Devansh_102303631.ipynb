# %% [markdown]
# <a href="https://colab.research.google.com/github/De-Coder05/Assignment-Topsis/blob/main/Devansh_102303631.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TOPSIS Implementation
# ## Roll Number: 102303631
# ### Devansh Wadhwani

# %%
# !pip install Topsis-Devansh-102303631

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !topsis data.xlsx "1,1,1,1,1" "+,+,+,+,+" result.csv
# Out:
# Result file 'result.csv' generated successfully.

# %%
df = pd.read_csv('result.csv')
print(df)
# Out:
#   Fund Name    P1    P2   P3    P4     P5  Topsis Score  Rank
# 0        M1  0.84  0.71  6.7  42.1  12.59      0.563692     3
# 1        M2  0.91  0.83  7.0  31.7  10.11      0.513032     4
# 2        M3  0.79  0.62  4.8  46.7  13.23      0.439177     6
# 3        M4  0.78  0.61  6.4  42.4  12.55      0.491956     5
# 4        M5  0.94  0.88  3.6  62.2  16.91      0.641886     2
# 5        M6  0.88  0.77  6.5  51.5  14.91      0.738148     1
# 6        M7  0.66  0.44  5.3  48.9  13.83      0.407390     8
# 7        M8  0.93  0.86  3.4  37.0  10.55      0.408499     7

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Fund Name'], df['Topsis Score'], color='skyblue')
plt.xlabel('Fund Name')
plt.ylabel('Topsis Score')
plt.title('Topsis Score for each Fund')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('result_graph.png')
plt.show()
